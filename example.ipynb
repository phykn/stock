# %%
import matplotlib.pyplot as plt
from src.cauchy import generate_data

# %%
n = 1000
x = generate_data(num = n)
y = generate_data(num = n)
z = generate_data(num = n)

plt.title('Simulated Stock Prices using Cauchy Distribution')
plt.plot(x, label = 'Stock 1')
plt.plot(y, label = 'Stock 2')
plt.plot(z, label = 'Stock 3')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.xlim(0, n)
plt.ylim(bottom = 0)
plt.legend()
plt.show()
